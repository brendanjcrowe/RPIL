# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = np.random.multivariate_normal([5, 5], [[0.5, 0],[0, 10]], 100)
b = np.random.multivariate_normal([5, 5], [[10, 0],[0, 0.5]], 100)
c = np.random.multivariate_normal([10, 10], [[3,0.1],[1, 2]], 100)
d = np.concatenate((a, b, c), axis=0)
data = pd.DataFrame(d, columns=['x', 'y'])
data
data['g'] = np.concatenate((np.zeros(100), np.ones(100), np.full(100, 2)), axis=0)
# Out:
# <ipython-input-2-8482c292a713>:3: RuntimeWarning: covariance is not positive-semidefinite.
#   c = np.random.multivariate_normal([10, 10], [[3,0.1],[1, 2]], 100)

# %%
data
# Out:
#              x          y    g
# 0     5.185784   4.750227  0.0
# 1     5.572968   1.524917  0.0
# 2     5.238431   7.292381  0.0
# 3     4.560233   9.153827  0.0
# 4     4.089588   8.599211  0.0
# ..         ...        ...  ...
# 295  10.717539  10.300435  2.0
# 296  11.106692   9.044012  2.0
# 297   9.629724   7.045491  2.0
# 298   9.922296   8.401940  2.0
# 299  11.161946   9.237285  2.0
#
# [300 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.scatterplot('x', 'y', hue='g',data=data, palette=['red', 'blue', 'green'], ax=ax)

# %%
X = np.array([[1, 2],[1, 2], [1,2]])

# %%
y = np.array([X for _ in range(4)])

# %%
y.shape
# Out:
# (4, 3, 2)
