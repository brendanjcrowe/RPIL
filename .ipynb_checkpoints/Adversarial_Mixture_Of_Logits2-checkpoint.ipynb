# %% [markdown]
# # Example of Adversarial Mixuture of Logistic Regression Models

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from mixture_of_logistic_models import MixtureOfLogits
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
data = pd.read_table('mountain_car_demo.txt', sep=' ', header=0,names=['pos', 'vel', 'action', 'reward'], skiprows=1, index_col=False)
data
# Out:
#            pos       vel  action  reward
# 0    -0.422633 -0.001758     0.0    -1.0
# 1    -0.426137 -0.003504     0.0    -1.0
# 2    -0.431361 -0.005225     0.0    -1.0
# 3    -0.438269 -0.006908     0.0    -1.0
# 4    -0.446809 -0.008541     0.0    -1.0
# ...        ...       ...     ...     ...
# 1247  0.344660  0.035769     2.0    -1.0
# 1248  0.380151  0.035491     2.0    -1.0
# 1249  0.415599  0.035448     2.0    -1.0
# 1250  0.451251  0.035652     2.0    -1.0
# 1251  0.487364  0.036114     2.0    -1.0
#
# [1252 rows x 4 columns]

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.3'

# %% [markdown]
# ### Original Data

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(data.pos, data.vel, hue=data.action, palette=['red', 'green', 'blue' ])

# %%
for i in range(20):
    print(np.random.randint(0, 3))
# Out:
# 0
# 1
# 2
# 1
# 1
# 0
# 1
# 1
# 2
# 1
# 2
# 2
# 1
# 1
# 1
# 1
# 2
# 0
# 0
# 2

# %% [markdown]
# ## Corrupt Data

# %%
demos  = pd.read_table('mountain_car_demo.txt',header=None,sep=' ', nrows=1)
demos = demos.drop(13, axis=1)
data['demo'] = 0
demos[0] -=1
cnt = 0
for column in demos.columns:
    for i in range(cnt, cnt+demos[column][0]):
        data.at[i, 'demo'] = column
        if column in [0,1,2,3,4,5,6]:
            data.at[i, 'action'] = np.random.randint(0,3)
    cnt += demos[column][0]

# %% [markdown]
# ### Corrupted Data

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(data.pos, data.vel, hue=data.action, palette=['red', 'green', 'blue' ])

# %% [markdown]
# ## Assuming Correct Demonstrations

# %%
X = data.drop(['action', 'reward'], axis=1).to_numpy()
y = data.action.to_numpy()

# %%
model = LogisticRegression(
                        penalty='none',
                        multi_class='multinomial',
                        fit_intercept=True,
                        n_jobs=-1
                    ).fit(X, y)

# %% [markdown]
# ### Results

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(
    data.pos,
    data.vel,
    hue=model.predict( data.drop(['reward', 'action'], axis=1)),
    palette=['red', 'green', 'blue'])

# %% [markdown]
# ## Assuming we have two demonstrators

# %%
demos = [
    [0, 84],
    [85, 190],
    [191, 293],
    [294, 398],
    [399, 487],
    [488, 591],
    [592, 693],
    [694, 777],
    [778, 867],
    [868, 954],
    [955, 1057],
    [1058, 1146],
    [1147, 1251]
]
model = MixtureOfLogits().fit(X, y, demos, 7)

# %%
model1, model2 = model.result()

# %% [markdown]
# ### Result for Model1

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(
    data.pos,
    data.vel,
    hue=model1.predict( data.drop(['reward', 'action'], axis=1)),
    palette=['red', 'green', 'blue'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-85ec0a4c751d> in <module>
#       1 fig, ax = plt.subplots(figsize=(12, 7))
# ----> 2 ax = sns.scatterplot(
#       3     data.pos,
#       4     data.vel,
#       5     hue=model1.predict( data.drop(['reward', 'action'], axis=1)),
#
# ~/anaconda3/envs/irl/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1388                 legend="brief", ax=None, **kwargs):
#    1389
# -> 1390     p = _ScatterPlotter(
#    1391         x=x, y=y, hue=hue, style=style, size=size, data=data,
#    1392         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~/anaconda3/envs/irl/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     891         )
#     892
# --> 893         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     894         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     895         self.parse_style(plot_data["style"], markers, None, style_order)
#
# ~/anaconda3/envs/irl/lib/python3.8/site-packages/seaborn/relational.py in parse_hue(self, data, palette, order, norm)
#     367             cmap = None
#     368             limits = None
# --> 369             levels, palette = self.categorical_to_palette(
#     370                 # List comprehension here is required to
#     371                 # overcome differences in the way pandas
#
# ~/anaconda3/envs/irl/lib/python3.8/site-packages/seaborn/relational.py in categorical_to_palette(self, data, order, palette)
#     214                 if len(palette) != n_colors:
#     215                     err = "The palette list has the wrong number of colors."
# --> 216                     raise ValueError(err)
#     217                 colors = palette
#     218             else:
#
# ValueError: The palette list has the wrong number of colors.

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(
    data.pos,
    data.vel,
    hue=model2.predict( data.drop(['reward', 'action'], axis=1)),
    palette=['red',  'blue'])

# %%
a = np.ones((3, 2))
b = np.array([[1, 2],[1, 2],[1, 2]])
np.multiply(a, b)

# %%
gammas = model.gammas
for i, demo in enumerate(demos):
    print('Gamma model 1 for demo ' + str(i) + ': ' + str(np.unique(gammas[i][0][demo[0]:demo[1]+1])))
    #print('Gamma model 2 for demo ' + str(i) + ': ' + str(np.unique(gammas[i][1][demo[0]:demo[1]+1])))

# %%
for i, demo in enumerate(demos):
    #print('Gamma model 1 for demo ' + str(i) + ': ' + str(np.unique(gammas[i][0][demo[0]:demo[1]+1])))
    print('Gamma model 2 for demo ' + str(i) + ': ' + str(np.unique(gammas[i][1][demo[0]:demo[1]+1])))

# %% [markdown]
# ### Now we assume that one demonstrator is adversarial

# %%
from mixture_of_logistic_models import AdversarialLogits, Expert, Adversary

# %%
model = AdversarialLogits().fit(X, y, demos, 0.01)
expert, adversary = model.result()

# %%
gamma = expert.gamma
for i, demo in enumerate(demos):
    print('Gamma model 1 for demo ' + str(i) + ': ' + str(np.unique(gamma[demo[0]:demo[1]+1])))

# %%
gamma = adversary.gamma
for i, demo in enumerate(demos):
    print('Gamma model 1 for demo ' + str(i) + ': ' + str(np.unique(gamma[demo[0]:demo[1]+1])))

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.scatterplot(
    data.pos,
    data.vel,
    hue=expert.model.predict( data.drop(['reward', 'action'], axis=1)),
    palette=['red',  'blue'])
